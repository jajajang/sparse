# %%
# %run -i 220512_CodeForPaper_banditpart.py --d 10 --sigma=0.1 --delta 0.2 --repeat 10 --T0 30000
# Out:
# ...
#                                      CVXPY
#                                      v1.2.0
# ...
# (CVXPY) May 13 07:05:53 PM: Your problem has 110 variables, 2 constraints, and 0 parameters.
# (CVXPY) May 13 07:05:53 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 13 07:05:53 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) May 13 07:05:53 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 13 07:05:53 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) May 13 07:05:53 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) May 13 07:05:53 PM: Applying reduction Dcp2Cone
# ...

# %%
# %run -i 220512_CodeForPaper_banditpart.py --d 10 --sigma=0.1 --delta 0.2 --repeat 10 --T0 30000 --multiplier 0.1
# Out:
# ...
#                                      CVXPY
#                                      v1.2.0
# ...
# (CVXPY) May 14 05:54:10 PM: Your problem has 110 variables, 2 constraints, and 0 parameters.
# (CVXPY) May 14 05:54:10 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 14 05:54:10 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) May 14 05:54:10 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 14 05:54:10 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) May 14 05:54:10 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) May 14 05:54:10 PM: Applying reduction Dcp2Cone
# ...

# %%
np.sqrt(10)
# Out:
# 3.1622776601683795

# %%
# %run -i 220512_CodeForPaper_banditpart.py --d 10 --sigma=0.1 --delta 0.2 --repeat 10 --T0 30000 --multiplier 0.316227766
# Out:
# ...
#                                      CVXPY
#                                      v1.2.0
# ...
# (CVXPY) May 14 05:56:56 PM: Your problem has 110 variables, 2 constraints, and 0 parameters.
# (CVXPY) May 14 05:56:56 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 14 05:56:56 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) May 14 05:56:56 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 14 05:56:56 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) May 14 05:56:56 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) May 14 05:56:56 PM: Applying reduction Dcp2Cone
# ...

# %%
# %run -i 220512_CodeForPaper_banditpart.py --d 10 --sigma=0.1 --delta 0.2 --repeat 10 --T0 30000 --multiplier 0.5
# Out:
# ...
#                                      CVXPY
#                                      v1.2.0
# ...
# (CVXPY) May 14 06:03:18 PM: Your problem has 110 variables, 2 constraints, and 0 parameters.
# (CVXPY) May 14 06:03:18 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 14 06:03:18 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) May 14 06:03:18 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 14 06:03:18 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) May 14 06:03:18 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) May 14 06:03:18 PM: Applying reduction Dcp2Cone
# ...

# %%
# %run -i 220513_CodeForPaper_banditpart_actionsetChange.py --d 30 --sigma=0.1 --action_set uniform --delta 0.2 --repeat 10 --T0 10000
# Out:
# ...
#                                      CVXPY
#                                      v1.2.0
# ...
# (CVXPY) May 14 07:21:35 PM: Your problem has 990 variables, 2 constraints, and 0 parameters.
# (CVXPY) May 14 07:21:35 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 14 07:21:35 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) May 14 07:21:35 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 14 07:21:35 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) May 14 07:21:35 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) May 14 07:21:35 PM: Applying reduction Dcp2Cone
# ...

# %%
# %run -i 220513_CodeForPaper_banditpart_actionsetChange.py --d 20 --sigma=0.1 --action_set uniform --delta 0.2 --repeat 10 --T0 10000
# Out:
# ...
#                                      CVXPY
#                                     v1.1.18
# ...
# (CVXPY) May 15 12:11:23 AM: Your problem has 460 variables, 2 constraints, and 0 parameters.
# (CVXPY) May 15 12:11:23 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 15 12:11:23 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) May 15 12:11:23 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 15 12:11:23 AM: Compiling problem (target solver=MOSEK).
# (CVXPY) May 15 12:11:23 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) May 15 12:11:23 AM: Applying reduction Dcp2Cone
# ...

# %%
# %run -i 220513_CodeForPaper_banditpart_actionsetChange.py --d 10 --sigma=0.1 --action_set uniform --delta 0.2 --repeat 10 --T0 10000
# Out:
# ...
#                                      CVXPY
#                                     v1.1.18
# ...
# (CVXPY) May 15 12:08:59 AM: Your problem has 130 variables, 2 constraints, and 0 parameters.
# (CVXPY) May 15 12:08:59 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 15 12:08:59 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) May 15 12:08:59 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 15 12:08:59 AM: Compiling problem (target solver=MOSEK).
# (CVXPY) May 15 12:08:59 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) May 15 12:08:59 AM: Applying reduction Dcp2Cone
# ...
